# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json','r') as file:
    data=json.load(file)

# %%
data
# Out:
# {'username': 'ravindupathirana', 'key': '0f68fa37de7c98321d07e98d8a247c78'}

# %%
pip3 install kaggle
# Out:
#   Cell In[3], line 1
#     pip3 install kaggle
#          ^
# SyntaxError: invalid syntax

# %%
pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 549 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.5.3 in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (3.11)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: webencodings in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (0.5.1)
# Collecting text-unidecode
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 682 kB/s eta 0:00:01
# Requirement already satisfied: urllib3>=1.15.1 in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2.6.2)
# Requirement already satisfied: six>=1.10 in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: requests in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: certifi>=14.05.14 in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (2025.11.12)
# Collecting protobuf
#   Downloading protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
#      |████████████████████████████████| 427 kB 506 kB/s eta 0:00:01
# Requirement already satisfied: bleach in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: setuptools>=21.0.0 in /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages (from kaggle) (58.0.4)
# Collecting python-slugify
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Installing collected packages: text-unidecode, tqdm, python-slugify, protobuf, kaggle
# Successfully installed kaggle-1.7.4.5 protobuf-6.33.2 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.67.1
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()
# Out:
# /Volumes/My Disk 2/My Projects/Sentiment-Analysis-Project/env/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
api.datasets.list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 api.datasets.list()
#
# AttributeError: 'KaggleApi' object has no attribute 'datasets'

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
api.datasets.list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 api.datasets.list()
#
# AttributeError: 'KaggleApi' object has no attribute 'datasets'

# %%
import zipfile
with zipfile.Zipfile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 import zipfile
# ----> 2 with zipfile.Zipfile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
#       3     zip_ref.extractall('../artifacts/')
#
# AttributeError: module 'zipfile' has no attribute 'Zipfile'

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
